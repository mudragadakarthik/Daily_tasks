# %% [markdown]
# ### Clustering:
#  - Clustering is an unsupervised learning technique that groups similar data points into clusters without using labeled data.
#  - Data points within the same clusters are more similar to each other than to points in other clusters.
#
# ### What is K-Means clustering?
#  - K-Means Clustering is a unsupervised leaning algorithm that divides a dataset into K distinct clusters by minimizing the distance between data points and their respective cluster centroids.
#  - Each cluster is represented by a centroid, which is the mean of all data points in that cluster.
#
# ### Why is it called K-Means:
#  - K->no.of clusters
#  - Means->average(centroid) of points in a cluster
#
# ![image.png](attachment:30ef41fc-52a5-4206-ac7d-13cdad978723.png)
#
# ### How K-Means Works(Algorithm Steps):
#  - Choose the number of clusters K
#  - Initialize K centroids randomly
#  - Calculate distance between each data point and centroids
#  - Assign each point to the nearest centroid
#  - Update centroids by calculating the mean
#  - Repeat steps 3_5 until centoids do not change
#
# ### Formula used for K-means:
#
#
# ### Advantages of K-Means:
#  - Simple and easy to understand
#  - Fast and efficient
#  - Works well for large datasets
#
# ### Limitations of K-Means:
#  - Value of K must be chosen manually
#  - Sensitive to outliers
#  - Different initial centroids may give different results

# %% [raw]
# ### Example:
#  - Step-1: Dataset
#
#              point   X   Y
#                A     1   1
#                B     1   2
#                C     4   4
#                D     5   4
#
#  - Step-2: Initialize centroids(Randomly)
#           Centroid 1 (C1) =A(1,1)
#           Centroid 2 (C2) =C(4,4)
#
#  - Step-3: Calculate distance
#           Distance from A(1,1)
#
#  - Step-4: update
#
#  - Step-5: Repeat
#          Distance from A(1,1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
X=np.array([
    [1,1], #A
    [1,2], #B
    [4,4], #C
    [5,4]  #D
])

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
labels=kmeans.labels_
centroids=kmeans.cluster_centers_

# %%
print("Cluster labels:", labels)
print("Centroids:\n", centroids)
# Out:
# Cluster labels: [0 0 1 1]
# Centroids:
#  [[1.  1.5]
#  [4.5 4. ]]

# %%
plt.scatter(X[:,0], X[:,1], c=labels)
plt.scatter(centroids[:,0], centroids[:,1], marker='X',s=200)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("K-Means clustering Example")
plt.show()

# %% [markdown]
# ### Why Do We Need Elbow Method?
#  - K-Means requires the value of K beforehand.
#  - Choosing the wrong K leads to poor clustering.
#  - El
